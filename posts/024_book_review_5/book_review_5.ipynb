# %% [markdown]
# ---
# title: "Book Review 5"
# description: "[Your title here]"
# author: "Eric Zou"
# date: "10/12/2025"
# categories:
#   - Review
# ---

# %% [markdown]
# ## What It's About
#
# TODO: Capture the main ideas or narrative arc.
#
# ## What I Thought
#
# TODO: Be honest about pacing, clarity, and how much you actually enjoyed reading it.
#
# ## Reflecting
#
# TODO: Pull one or two quotes or ideas that you might want to revisit later in the series.
