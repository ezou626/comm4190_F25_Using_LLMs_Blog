# %% [markdown]
# ---
# title: "Book Review 6"
# description: "[Your title here]"
# author: "Eric Zou"
# date: "10/19/2025"
# categories:
#   - Review
# ---

# %% [markdown]
# ## What It's About
#
# TODO: Give a quick overview of the book in a way that future-you will actually remember.
#
# ## What I Thought
#
# TODO: Write down the moments where you strongly agreed, strongly disagreed, or felt weirdly conflicted.
#
# ## Reflecting
#
# TODO: End with one concrete way this book might change how you design or evaluate LLM systems.
